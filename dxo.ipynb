# %%
import numpy as np

# %%
from pandas import read_csv

# %%
data = read_csv('DXO.csv')

# %%
data
# Out:
#     ExposureContrast  Color   Autofocus  Texture  Noise  Artifacts  Flash  \
# 0                 47      57         41       32     59         41     59
# 1                 74      72         81       48     63         59     60
# 2                 60      59         77       46     45         38     63
# 3                 90      79         78       65     69         82     85
# 4                 88      86         96       67     71         66     84
# 5                 95      86         98       73     59         64     88
# 6                 82      73         94       65     75         68     82
# 7                 89      78         74       64     68         73     84
# 8                 89      77         83       65     69         83     81
# 9                 83      74         88       68     58         49     74
# 10                85      78         75       56     62         75     68
# 11                86      83         90       74     62         65     79
# 12                59      59         40       53     60         42     70
# 13                78      75         73       57     66         65     75
# 14                90      80         98       70     65         50     81
# 15                74      77         69       45     52         59     64
# 16                84      81         74       54     64         78     68
# 17                91      81         91       67     79         62     86
# 18                85      71         94       54     67         48     75
# 19                85      86         93       66     60         56     87
# 20                79      75         69       67     61         67     88
# 21                82      79         77       67     66         68     71
# 22                67      74         65       49     66         54     62
# 23                75      69         62       55     61         51     70
# 24                86      75         89       58     73         68     69
# 25                74      76         73       57     71         31     75
#
#     Zoom  Bokeh  Total  Verification
# 0     22     25     47           NaN
# 1     24     25     74           NaN
# 2     19     15     56           NaN
# 3     58     55    101           NaN
# 4     40     50    100           NaN
# 5     32     45     99           NaN
# 6     66     45    100           NaN
# 7     51     55     96           NaN
# 8     31     23     93           NaN
# 9     32     20     82           NaN
# 10    46     50     89           NaN
# 11    29     20     90           NaN
# 12    43     25     60           NaN
# 13    39     15     81           NaN
# 14    24     30     90           NaN
# 15    22     25     70           NaN
# 16    35     25     85           NaN
# 17    65     50    104           NaN
# 18    30     25     82           NaN
# 19    33     40     92           NaN
# 20    23     40     84           NaN
# 21    35     25     87           NaN
# 22    25     25     70           NaN
# 23    23     35     72           NaN
# 24    50     50     94           NaN
# 25    28     30     74           NaN

# %%
Y = data['Total']

# %%
Y
# Out:
# 0      47
# 1      74
# 2      56
# 3     101
# 4     100
# 5      99
# 6     100
# 7      96
# 8      93
# 9      82
# 10     89
# 11     90
# 12     60
# 13     81
# 14     90
# 15     70
# 16     85
# 17    104
# 18     82
# 19     92
# 20     84
# 21     87
# 22     70
# 23     72
# 24     94
# 25     74
# Name: Total, dtype: int64

# %%
X = data[['ExposureContrast','Color ','Autofocus','Texture','Noise','Artifacts','Flash','Zoom','Bokeh']]

# %%
X
# Out:
#     ExposureContrast  Color   Autofocus  Texture  Noise  Artifacts  Flash  \
# 0                 47      57         41       32     59         41     59
# 1                 74      72         81       48     63         59     60
# 2                 60      59         77       46     45         38     63
# 3                 90      79         78       65     69         82     85
# 4                 88      86         96       67     71         66     84
# 5                 95      86         98       73     59         64     88
# 6                 82      73         94       65     75         68     82
# 7                 89      78         74       64     68         73     84
# 8                 89      77         83       65     69         83     81
# 9                 83      74         88       68     58         49     74
# 10                85      78         75       56     62         75     68
# 11                86      83         90       74     62         65     79
# 12                59      59         40       53     60         42     70
# 13                78      75         73       57     66         65     75
# 14                90      80         98       70     65         50     81
# 15                74      77         69       45     52         59     64
# 16                84      81         74       54     64         78     68
# 17                91      81         91       67     79         62     86
# 18                85      71         94       54     67         48     75
# 19                85      86         93       66     60         56     87
# 20                79      75         69       67     61         67     88
# 21                82      79         77       67     66         68     71
# 22                67      74         65       49     66         54     62
# 23                75      69         62       55     61         51     70
# 24                86      75         89       58     73         68     69
# 25                74      76         73       57     71         31     75
#
#     Zoom  Bokeh
# 0     22     25
# 1     24     25
# 2     19     15
# 3     58     55
# 4     40     50
# 5     32     45
# 6     66     45
# 7     51     55
# 8     31     23
# 9     32     20
# 10    46     50
# 11    29     20
# 12    43     25
# 13    39     15
# 14    24     30
# 15    22     25
# 16    35     25
# 17    65     50
# 18    30     25
# 19    33     40
# 20    23     40
# 21    35     25
# 22    25     25
# 23    23     35
# 24    50     50
# 25    28     30

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# model = LinearRegression()

# %%
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.1)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([81.06328269, 94.28514685, 85.39376964])

# %%
list(Y_test)
# Out:
# [81, 94, 85]

# %%
print(model.coef_)
# Out:
# [0.23878247 0.22435323 0.21389948 0.21871888 0.23444831 0.21068883
#  0.12425724 0.16259916 0.12440691]

# %%
print(model.intercept_)
# Out:
# -29.16500674770957
